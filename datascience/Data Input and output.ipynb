# %%
import pandas as pd

# %%
pd.read_csv("ticket_results.csv")
# Out:
#         Case ID                                        Description  \
# 0    0139179213           Case ID:4253322302|Seller ID:11189305212
# 1    0139174414                                         HSA Issue
# 2    0139163482  Seller store always rejected  Case ID:42512846...
# 3    0139159669  *911* Seller 911 Contact Seller can't select b...
# 4    0139156088  [Amazon Stores for Sellers] Seller brand entit...
# 5    0139156111       TAM-SP-Case Assist <--Do Not Edit 4233848352
# 6    0139145888  [WhereIsMyAd] investigation request case 42343...
# 7    0139054784  Brand Registry Stores and HSA --> *Do Not Edit...
# 8    0139051008  *911* Seller 911 Contact HSA - Brand not avail...
# 9    0139043655  *911* Seller 911 Contact HSA - Brand not avail...
# 10   0139038719  [Amazon Stores for Sellers] Seller brand entit...
# 11   0139022651           Case ID:4225769282|Seller ID:12490035035
# 12   0138917287                        Brand not appearing for HSA
# ...

# %%
df = pd.read_csv("ticket_results.csv")

# %%
df.to_csv("My_output",index=False)
