# %%
import numpy as np

# %%
import pandas as pd

# %%
labels = ['a','b','c']
my_data = [10,20,30]
arr = np.array(my_data)
d = {'a':10,'b':20,'c':30}

# %%
pd.Series(data = my_data)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_data,labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(data = [sum,print,len])
# Out:
# 0      <built-in function sum>
# 1    <built-in function print>
# 2      <built-in function len>
# dtype: object

# %%
ser1 = pd.Series([1,2,3,4],['USA','Germany','USSR','Japan'])

# %%
ser1
# Out:
# USA        1
# Germany    2
# USSR       3
# Japan      4
# dtype: int64

# %%
ser2 = pd.Series([1,2,3,4],['USA','Germany',"Italy","Japan"])

# %%
ser2
# Out:
# USA        1
# Germany    2
# Italy      3
# Japan      4
# dtype: int64

# %%
ser2["USA"]
# Out:
# 1

# %%
from numpy.random import randn

# %%
np.random.seed(101)

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],["W","X","Y","Z"])

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
df['new'] =df['W'] + df["Y"]

# %%
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1,inplace=True)

# %%
df.shape
# Out:
# (5, 4)

# %%
df.loc["A"]
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[2]
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %%
df.loc["B","Y"]
# Out:
# -0.84807698340363147

# %%
df.loc[["A",'B'],['W','Y']]
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %%
outside = ['G1','G1','G1','G2','G2','G2']
inside = [1,2,3,1,2,3]
hier_index = list(zip(outside,inside))
hier_index = pd.MultiIndex.from_tuples(hier_index)

# %%
hier_index
# Out:
# MultiIndex(levels=[['G1', 'G2'], [1, 2, 3]],
#            labels=[[0, 0, 0, 1, 1, 1], [0, 1, 2, 0, 1, 2]])

# %%
df = pd.DataFrame(randn(6,2),hier_index,['A','B'])

# %%
df
# Out:
#              A         B
# G1 1 -0.278113  1.585707
#    2 -0.041466 -0.311822
#    3 -1.276537  0.276738
# G2 1  0.174638  1.892998
#    2  0.549735 -1.213690
#    3 -1.022143 -0.661559

# %%
df.loc['G1'].loc[2]
# Out:
# A   -0.041466
# B   -0.311822
# Name: 2, dtype: float64

# %%
df.index.names=['Groups','Names']

# %%
df
# Out:
#                      A         B
# Groups Names
# G1     1     -0.278113  1.585707
#        2     -0.041466 -0.311822
#        3     -1.276537  0.276738
# G2     1      0.174638  1.892998
#        2      0.549735 -1.213690
#        3     -1.022143 -0.661559

# %%
df.loc['G1']
# Out:
#               A         B
# Names
# 1     -0.278113  1.585707
# 2     -0.041466 -0.311822
# 3     -1.276537  0.276738

# %%
df.xs(1,level = 'Names')
# Out:
#                A         B
# Groups
# G1     -0.278113  1.585707
# G2      0.174638  1.892998

# %%
d = {'A':[1,2,np.nan],'B':[5,np.nan,np.nan],'C':[1,2,3]}

# %%
df =pd.DataFrame(d)

# %%
df
# Out:
#      A    B  C
# 0  1.0  5.0  1
# 1  2.0  NaN  2
# 2  NaN  NaN  3

# %%
df.dropna(axis=1)
# Out:
#    C
# 0  1
# 1  2
# 2  3

# %%
df.dropna()
# Out:
#      A    B  C
# 0  1.0  5.0  1

# %%
df.fillna(value='FILL VALUE')
# Out:
#             A           B  C
# 0           1           5  1
# 1           2  FILL VALUE  2
# 2  FILL VALUE  FILL VALUE  3

# %%
#fill the missing value with mean of column
df['A'].fillna(value=df['A'].mean())
# Out:
# 0    1.0
# 1    2.0
# 2    1.5
# Name: A, dtype: float64

# %%
data = {'company':["GOOG","GOOG","MSFT","MSFT","FB","FB"],
       'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
       'Sales':[200,120,340,124,243,350],
       'Sales2':[200,120,340,124,243,350]}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#     Person  Sales  Sales2 company
# 0      Sam    200     200    GOOG
# 1  Charlie    120     120    GOOG
# 2      Amy    340     340    MSFT
# 3  Vanessa    124     124    MSFT
# 4     Carl    243     243      FB
# 5    Sarah    350     350      FB

# %%
byComp = df.groupby('company')

# %%
byComp.describe().transpose()
# Out:
# company    FB                                                         GOOG  \
#         count   mean        std    min     25%    50%     75%    max count
# Sales     2.0  296.5  75.660426  243.0  269.75  296.5  323.25  350.0   2.0
# Sales2    2.0  296.5  75.660426  243.0  269.75  296.5  323.25  350.0   2.0
#
# company         ...                  MSFT                                   \
#           mean  ...      75%    max count   mean         std    min    25%
# Sales    160.0  ...    180.0  200.0   2.0  232.0  152.735065  124.0  178.0
# Sales2   160.0  ...    180.0  200.0   2.0  232.0  152.735065  124.0  178.0
#
# company
#            50%    75%    max
# Sales    232.0  286.0  340.0
# Sales2   232.0  286.0  340.0
#
# [2 rows x 24 columns]
